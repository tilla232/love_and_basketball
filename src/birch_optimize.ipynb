# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
from sklearn.cluster import Birch
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize

# %%
# Constants - The master stat (feature) list, and the corresponding player data.
stats_list = ['MP_x','FG','FGA','2P','2PA','3P','3PA','FT','FTA','ORB', 'DRB', 'TRB', 'AST', 'STL','BLK','TOV','PF','PTS','FG%','2P%','3P%', 'eFG%', 'FT%', 'TS%_x', 'PER', '3PAr','FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','ORtg', 'DRtg', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM','VORP', 'dist', 'spd', 'tchs', 'pass', 'sast', 'ftast', 'dfgm','dfga']
df = pd.read_csv('../data/final_stats.csv')
df.set_index('player_year',inplace=True)
df.fillna(value=0,inplace=True)

# %%
feature_space = ['MP_x','tchs','2P','3P','3PA','FTr','TS%_x','ORB','TRB','AST%','STL%','BLK%','3PAr','DWS','DBPM','dist','dfga']

# %%
# Optimizing BIRCH
X = df[feature_space]
X = normalize(X)

threshold_list = np.linspace(0.1,4,50)
branch_list = np.arange(0,120,10)
comp_list = [2,3,4,5]
max_score = [0,0,0,0]

for t in threshold_list:
    print ('threshold = {}'.format(t))
    for b in branch_list:
        for c in comp_list:
            pca = PCA(n_components=c,whiten=True,svd_solver='full')
            reduced = pca.fit_transform(X)
            
            birch = Birch(threshold=t,branching_factor=b,n_clusters=None)
            try:
                birch.fit(reduced)
            except:
                continue
            try:
                score = silhouette_score(reduced,birch.labels_)
            except:
                continue
            if score > max_score[0]:
                max_score = [score,'threshold:{}'.format(t),'branching:{}'.format(b),'{} pca components'.format(c)]
                print ('new max score: {}'.format(max_score) + '{} clusters'.format(len(np.unique(birch.labels_))))
# Out:
# threshold = 0.1
# new max score: [0.28789277833066979, 'threshold:0.1', 'branching:10', '2 pca components']284 clusters
# new max score: [0.30235196022519839, 'threshold:0.1', 'branching:20', '2 pca components']272 clusters
# new max score: [0.31526837476948594, 'threshold:0.1', 'branching:30', '2 pca components']264 clusters
# new max score: [0.32591314329101095, 'threshold:0.1', 'branching:50', '2 pca components']256 clusters
# new max score: [0.32954721528174646, 'threshold:0.1', 'branching:90', '2 pca components']251 clusters
# threshold = 0.17959183673469387
# threshold = 0.25918367346938775
# threshold = 0.3387755102040816
# threshold = 0.41836734693877553
# threshold = 0.49795918367346936
# threshold = 0.5775510204081632
# threshold = 0.6571428571428571
# threshold = 0.736734693877551
# threshold = 0.8163265306122448
# threshold = 0.8959183673469387
# new max score: [0.36438150449398515, 'threshold:0.8959183673469387', 'branching:10', '2 pca components']6 clusters
# threshold = 0.9755102040816326
# threshold = 1.0551020408163265
# new max score: [0.36684413844647573, 'threshold:1.0551020408163265', 'branching:10', '2 pca components']5 clusters
# threshold = 1.1346938775510205
# threshold = 1.2142857142857144
# threshold = 1.2938775510204081
# threshold = 1.373469387755102
# threshold = 1.453061224489796
# new max score: [0.36843990606027671, 'threshold:1.453061224489796', 'branching:10', '2 pca components']2 clusters
# threshold = 1.5326530612244897
# threshold = 1.6122448979591837
# threshold = 1.6918367346938776
# threshold = 1.7714285714285714
# new max score: [0.36928274485359469, 'threshold:1.7714285714285714', 'branching:10', '2 pca components']2 clusters
# threshold = 1.8510204081632653
# threshold = 1.9306122448979592
# threshold = 2.010204081632653
# threshold = 2.0897959183673467
# threshold = 2.169387755102041
# threshold = 2.2489795918367346
# threshold = 2.3285714285714287
# threshold = 2.4081632653061225
# threshold = 2.487755102040816
# threshold = 2.5673469387755103
# threshold = 2.646938775510204
# threshold = 2.726530612244898
# threshold = 2.806122448979592
# threshold = 2.8857142857142857
# threshold = 2.9653061224489794
# threshold = 3.0448979591836736
# threshold = 3.1244897959183673
# threshold = 3.204081632653061
# threshold = 3.283673469387755
# threshold = 3.363265306122449
# threshold = 3.4428571428571426
# threshold = 3.522448979591837
# threshold = 3.6020408163265305
# threshold = 3.6816326530612242
# threshold = 3.7612244897959184
# threshold = 3.840816326530612
# threshold = 3.920408163265306
# threshold = 4.0

# %%
# Optimizing BIRCH, round 2
X = df[feature_space]
X = normalize(X)

threshold_list = np.linspace(0.8,0.9,20)
branch_list = np.arange(1,21,1)
comp_list = [2,3,4,5]

for t in threshold_list:
    max_score = [0,0,0,0] # reset high score for each threshold value

    print ('threshold = {}'.format(t))
    for b in branch_list:
        for c in comp_list:
            pca = PCA(n_components=c,whiten=True,svd_solver='full')
            reduced = pca.fit_transform(X)
            
            birch = Birch(threshold=t,branching_factor=b,n_clusters=None)
            try:
                birch.fit(reduced)
            except:
                continue
            try:
                score = silhouette_score(reduced,birch.labels_)
            except:
                continue
            if score > max_score[0]:
                max_score = [score,'threshold:{}'.format(t),'branching:{}'.format(b),'{} pca components'.format(c)]
                print ('new max score: {}'.format(max_score) + '{} clusters'.format(len(np.unique(birch.labels_))))
# Out:
# threshold = 0.8
# new max score: [0.31503884977845314, 'threshold:0.8', 'branching:2', '2 pca components']8 clusters
# new max score: [0.34288276239147858, 'threshold:0.8', 'branching:6', '2 pca components']7 clusters
# new max score: [0.34366334062058729, 'threshold:0.8', 'branching:7', '2 pca components']7 clusters
# threshold = 0.8052631578947369
# new max score: [0.30697432259376611, 'threshold:0.8052631578947369', 'branching:2', '2 pca components']9 clusters
# new max score: [0.31676503194669742, 'threshold:0.8052631578947369', 'branching:3', '2 pca components']8 clusters
# new max score: [0.32395892515083563, 'threshold:0.8052631578947369', 'branching:7', '2 pca components']7 clusters
# threshold = 0.8105263157894738
# new max score: [0.32404443548203077, 'threshold:0.8105263157894738', 'branching:2', '2 pca components']10 clusters
# threshold = 0.8157894736842106
# new max score: [0.3133007348925545, 'threshold:0.8157894736842106', 'branching:2', '2 pca components']10 clusters
# new max score: [0.31668830183765956, 'threshold:0.8157894736842106', 'branching:3', '2 pca components']7 clusters
# threshold = 0.8210526315789474
# new max score: [0.32433655819415314, 'threshold:0.8210526315789474', 'branching:2', '2 pca components']10 clusters
# threshold = 0.8263157894736842
# new max score: [0.30870892448608023, 'threshold:0.8263157894736842', 'branching:2', '2 pca components']9 clusters
# new max score: [0.31594816115626662, 'threshold:0.8263157894736842', 'branching:3', '2 pca components']7 clusters
# new max score: [0.32032185215425008, 'threshold:0.8263157894736842', 'branching:4', '2 pca components']7 clusters
# threshold = 0.8315789473684211
# new max score: [0.28681695567052401, 'threshold:0.8315789473684211', 'branching:2', '2 pca components']9 clusters
# new max score: [0.31572807781820805, 'threshold:0.8315789473684211', 'branching:3', '2 pca components']8 clusters
# new max score: [0.3685189893889575, 'threshold:0.8315789473684211', 'branching:4', '2 pca components']6 clusters
# threshold = 0.8368421052631579
# new max score: [0.29410057611002055, 'threshold:0.8368421052631579', 'branching:2', '2 pca components']8 clusters
# new max score: [0.3128676286610575, 'threshold:0.8368421052631579', 'branching:3', '2 pca components']8 clusters
# new max score: [0.36200408024372116, 'threshold:0.8368421052631579', 'branching:4', '2 pca components']6 clusters
# new max score: [0.36287772507827137, 'threshold:0.8368421052631579', 'branching:6', '2 pca components']6 clusters
# threshold = 0.8421052631578948
# new max score: [0.3043797868289278, 'threshold:0.8421052631578948', 'branching:2', '2 pca components']9 clusters
# new max score: [0.32758571763753797, 'threshold:0.8421052631578948', 'branching:4', '2 pca components']7 clusters
# new max score: [0.3613783814532176, 'threshold:0.8421052631578948', 'branching:5', '2 pca components']6 clusters
# new max score: [0.36160711688151975, 'threshold:0.8421052631578948', 'branching:6', '2 pca components']6 clusters
# threshold = 0.8473684210526317
# new max score: [0.36979897872378259, 'threshold:0.8473684210526317', 'branching:2', '2 pca components']6 clusters
# threshold = 0.8526315789473684
# new max score: [0.36782936699772456, 'threshold:0.8526315789473684', 'branching:2', '2 pca components']6 clusters
# threshold = 0.8578947368421053
# new max score: [0.36829693399579416, 'threshold:0.8578947368421053', 'branching:2', '2 pca components']6 clusters
# threshold = 0.8631578947368421
# new max score: [0.33511244793274886, 'threshold:0.8631578947368421', 'branching:2', '2 pca components']6 clusters
# new max score: [0.36550883999333311, 'threshold:0.8631578947368421', 'branching:3', '2 pca components']5 clusters
# new max score: [0.36629351051391768, 'threshold:0.8631578947368421', 'branching:5', '2 pca components']5 clusters
# threshold = 0.868421052631579
# new max score: [0.33740813359989191, 'threshold:0.868421052631579', 'branching:2', '2 pca components']6 clusters
# new max score: [0.36550883999333311, 'threshold:0.868421052631579', 'branching:3', '2 pca components']5 clusters
# new max score: [0.36629351051391768, 'threshold:0.868421052631579', 'branching:5', '2 pca components']5 clusters
# threshold = 0.8736842105263158
# new max score: [0.31648481591748384, 'threshold:0.8736842105263158', 'branching:2', '2 pca components']6 clusters
# new max score: [0.36506203892433953, 'threshold:0.8736842105263158', 'branching:3', '2 pca components']5 clusters
# new max score: [0.36513392487621177, 'threshold:0.8736842105263158', 'branching:4', '2 pca components']5 clusters
# threshold = 0.8789473684210527
# new max score: [0.32374690949517815, 'threshold:0.8789473684210527', 'branching:2', '2 pca components']8 clusters
# new max score: [0.33216330778510894, 'threshold:0.8789473684210527', 'branching:3', '2 pca components']7 clusters
# new max score: [0.36794147999250842, 'threshold:0.8789473684210527', 'branching:4', '2 pca components']6 clusters
# threshold = 0.8842105263157896
# new max score: [0.3219825215886164, 'threshold:0.8842105263157896', 'branching:2', '2 pca components']8 clusters
# new max score: [0.33141759424287859, 'threshold:0.8842105263157896', 'branching:3', '2 pca components']7 clusters
# new max score: [0.36794147999250842, 'threshold:0.8842105263157896', 'branching:4', '2 pca components']6 clusters
# threshold = 0.8894736842105263
# new max score: [0.32104428511620586, 'threshold:0.8894736842105263', 'branching:2', '2 pca components']8 clusters
# new max score: [0.33789157062722486, 'threshold:0.8894736842105263', 'branching:3', '2 pca components']7 clusters
# new max score: [0.36794147999250842, 'threshold:0.8894736842105263', 'branching:4', '2 pca components']6 clusters
# threshold = 0.8947368421052632
# new max score: [0.31991353126455957, 'threshold:0.8947368421052632', 'branching:2', '2 pca components']8 clusters
# new max score: [0.32511218606313541, 'threshold:0.8947368421052632', 'branching:3', '2 pca components']7 clusters
# new max score: [0.36802748953106845, 'threshold:0.8947368421052632', 'branching:4', '2 pca components']6 clusters
# threshold = 0.9
# new max score: [0.31889182972265567, 'threshold:0.9', 'branching:2', '2 pca components']8 clusters
# new max score: [0.32552329826533499, 'threshold:0.9', 'branching:3', '2 pca components']8 clusters
# new max score: [0.36779021967629161, 'threshold:0.9', 'branching:4', '2 pca components']6 clusters
