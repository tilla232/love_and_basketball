# %%
import pandas as pd
import numpy as np

from sklearn.cluster import AffinityPropagation
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score, calinski_harabaz_score
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import normalize

from agglomerative import get_data
from cluster_visual import plot_tsne_scatter

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Constants - The master stat (feature) list, and the corresponding player data.
stats_list = ['MP_x','FG','FGA','2P','2PA','3P','3PA','FT','FTA','ORB', 'DRB', 'TRB', 'AST', 'STL','BLK','TOV','PF','PTS','FG%','2P%','3P%', 'eFG%', 'FT%', 'TS%_x', 'PER', '3PAr','FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','ORtg', 'DRtg', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM','VORP', 'dist', 'spd', 'tchs', 'pass', 'sast', 'ftast', 'dfgm','dfga']
df = pd.read_csv('../data/final_stats.csv')
df.set_index('player_year',inplace=True)
df.fillna(value=0,inplace=True)

# %%
# After lot's of feature space randomization and analysis, let's use what we've learned to craft a feature space
# manually.  Here's our (tentative) new stats list:
new_stats_list = ['MP_x','2P','3P','3PA','FTr','TS%_x','ORB','TRB','AST%','STL%','BLK%','3PAr','DWS','DBPM','dist','dfga']

# %%
# Let's optimize a Gaussian Mixture model:
X = df[new_stats_list]

cluster_list = range(10,25)
pca_components = [2,3,4,5]
covar_list = ['full','diag','tied','spherical']

for k in cluster_list:
    print "{} clusters".format(k)
    for com in pca_components:
        for covar in covar_list:
            gmm = GaussianMixture(n_components=k,covariance_type=covar,n_init=10,random_state=23)
            pca = PCA(n_components=com,whiten=True,svd_solver='full')
            reduced = pca.fit_transform(X)
            gmm.fit(reduced)
            
            try:
                silhouette = silhouette_score(reduced,gmm.predict(reduced))
                calinski = calinski_harabaz_score(reduced,gmm.predict(reduced))
            except:
                continue

            X['label'] = gmm.predict(reduced)
            if X.loc['Nikola Jokic/2016-17']['label'] == X.loc['Marc Gasol/2016-17']['label'] and silhouette > 0.4:
                print("{} components| covariance type: {} | silhouette: {} | calinski: {}".format(com,covar,silhouette,calinski))
                print("Silhouette * Calinski = {}".format(silhouette*calinski))
# Out:
# 10 clusters
# /Users/robertcorboy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 11 clusters
# 12 clusters
# 13 clusters
# 14 clusters
# 15 clusters
# 16 clusters
# 4 components| covariance type: spherical | silhouette: 0.429010789479 | calinski: 428.670202253
# Silhouette * Calinski = 183.904141894
# 17 clusters
# 3 components| covariance type: spherical | silhouette: 0.401774966444 | calinski: 643.364230862
# Silhouette * Calinski = 258.487642266
# 4 components| covariance type: spherical | silhouette: 0.402868787223 | calinski: 397.510004555
# Silhouette * Calinski = 160.144373444
# 18 clusters
# 19 clusters
# 3 components| covariance type: diag | silhouette: 0.417491565731 | calinski: 619.465446424
# Silhouette * Calinski = 258.621599144
# 20 clusters
# 3 components| covariance type: diag | silhouette: 0.407771819001 | calinski: 567.390821846
# Silhouette * Calinski = 231.365987508
# 3 components| covariance type: tied | silhouette: 0.440264333264 | calinski: 704.509470467
# Silhouette * Calinski = 310.170392293
# 21 clusters
# 22 clusters
# 2 components| covariance type: diag | silhouette: 0.403898802186 | calinski: 1254.77128922
# Silhouette * Calinski = 506.800620732
# 2 components| covariance type: tied | silhouette: 0.449269745024 | calinski: 1274.35182973
# Silhouette * Calinski = 572.527721613
# 23 clusters
# 3 components| covariance type: spherical | silhouette: 0.446905786439 | calinski: 701.501839231
# Silhouette * Calinski = 313.50523115
# 24 clusters

# %% [markdown]
# We start seeing our scores show up around k=16, let's tighten those parameter ranges a little bit, and up the number of initializations to truly tune this thing:

# %%
# Let's optimize a Gaussian Mixture model:
X = df[new_stats_list]

cluster_list = range(16,24)
pca_components = [2,3,4]
covar_list = ['full','diag','tied','spherical']

for k in cluster_list:
    print "{} clusters".format(k)
    for com in pca_components:
        for covar in covar_list:
            gmm = GaussianMixture(n_components=k,covariance_type=covar,n_init=100,random_state=23)
            pca = PCA(n_components=com,whiten=True,svd_solver='full')
            reduced = pca.fit_transform(X)
            gmm.fit(reduced)
            
            try:
                silhouette = silhouette_score(reduced,gmm.predict(reduced))
                calinski = calinski_harabaz_score(reduced,gmm.predict(reduced))
            except:
                continue

            X['label'] = gmm.predict(reduced)
            if X.loc['Nikola Jokic/2016-17']['label'] == X.loc['Marc Gasol/2016-17']['label'] and silhouette > 0.4:
                print("{} components| covariance type: {} | silhouette: {} | calinski: {}".format(com,covar,silhouette,calinski))
                print("Silhouette * Calinski = {}".format(silhouette*calinski))
# Out:
# 16 clusters
# /Users/robertcorboy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 17 clusters
# 18 clusters
# 19 clusters
# 3 components| covariance type: full | silhouette: 0.457492373491 | calinski: 598.867680962
# Silhouette * Calinski = 273.97739677
# 20 clusters
# 3 components| covariance type: full | silhouette: 0.484977693537 | calinski: 802.964913312
# Silhouette * Calinski = 389.42007165
# 3 components| covariance type: diag | silhouette: 0.494256365039 | calinski: 817.685890538
# Silhouette * Calinski = 404.146456001
# 3 components| covariance type: tied | silhouette: 0.504493446295 | calinski: 817.770171525
# Silhouette * Calinski = 412.55969211
# 3 components| covariance type: spherical | silhouette: 0.499597150193 | calinski: 800.564464287
# Silhouette * Calinski = 399.959724903
# 21 clusters
# 22 clusters
# 23 clusters

# %% [markdown]
# Alright - our best results were 20 clusters, 3 PCA components, and tied covariance type - let's run with those!

# %%
X = df[new_stats_list]
pca = PCA(n_components=3,whiten=True,svd_solver='full')
gmm = GaussianMixture(n_components=20,covariance_type='tied',n_init=200,verbose=1)

reduced = pca.fit_transform(X)
gmm.fit(reduced)

print "silhouette score = {}".format(silhouette_score(reduced,gmm.predict(reduced)))
print "calinski-harabasz score = {}".format(calinski_harabaz_score(reduced,gmm.predict(reduced)))
# Out:
# Initialization 0
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 1
#   Iteration 0
# Initialization converged: True
# Initialization 2
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 3
#   Iteration 0
# Initialization converged: True
# Initialization 4
#   Iteration 0
# Initialization converged: True
# Initialization 5
#   Iteration 0
# Initialization converged: True
# Initialization 6
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 7
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 8
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 9
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 10
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 11
#   Iteration 0
# Initialization converged: True
# Initialization 12
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 13
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 14
#   Iteration 0
# Initialization converged: True
# Initialization 15
#   Iteration 0
# Initialization converged: True
# Initialization 16
#   Iteration 0
# Initialization converged: True
# Initialization 17
#   Iteration 0
# Initialization converged: True
# Initialization 18
#   Iteration 0
# Initialization converged: True
# Initialization 19
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 20
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 21
#   Iteration 0
# Initialization converged: True
# Initialization 22
#   Iteration 0
# Initialization converged: True
# Initialization 23
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 24
#   Iteration 0
# Initialization converged: True
# Initialization 25
#   Iteration 0
# Initialization converged: True
# Initialization 26
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 27
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 28
#   Iteration 0
# Initialization converged: True
# Initialization 29
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 30
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 31
#   Iteration 0
# Initialization converged: True
# Initialization 32
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 33
#   Iteration 0
# Initialization converged: True
# Initialization 34
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 35
#   Iteration 0
# Initialization converged: True
# Initialization 36
#   Iteration 0
# Initialization converged: True
# Initialization 37
#   Iteration 0
# Initialization converged: True
# Initialization 38
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 39
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 40
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 41
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 42
#   Iteration 0
# Initialization converged: True
# Initialization 43
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 44
#   Iteration 0
# Initialization converged: True
# Initialization 45
#   Iteration 0
# Initialization converged: True
# Initialization 46
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 47
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 48
#   Iteration 0
# Initialization converged: True
# Initialization 49
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 50
#   Iteration 0
# Initialization converged: True
# Initialization 51
#   Iteration 0
# Initialization converged: True
# Initialization 52
#   Iteration 0
# Initialization converged: True
# Initialization 53
#   Iteration 0
# Initialization converged: True
# Initialization 54
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 55
#   Iteration 0
# Initialization converged: True
# Initialization 56
#   Iteration 0
# Initialization converged: True
# Initialization 57
#   Iteration 0
# Initialization converged: True
# Initialization 58
#   Iteration 0
# Initialization converged: True
# Initialization 59
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 60
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 61
#   Iteration 0
# Initialization converged: True
# Initialization 62
#   Iteration 0
# Initialization converged: True
# Initialization 63
#   Iteration 0
# Initialization converged: True
# Initialization 64
#   Iteration 0
# Initialization converged: True
# Initialization 65
#   Iteration 0
# Initialization converged: True
# Initialization 66
#   Iteration 0
# Initialization converged: True
# Initialization 67
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 68
#   Iteration 0
# Initialization converged: True
# Initialization 69
#   Iteration 0
#   Iteration 10
#   Iteration 20
# Initialization converged: True
# Initialization 70
#   Iteration 0
# Initialization converged: True
# Initialization 71
#   Iteration 0
# Initialization converged: True
# Initialization 72
#   Iteration 0
# Initialization converged: True
# Initialization 73
#   Iteration 0
# Initialization converged: True
# Initialization 74
#   Iteration 0
# Initialization converged: True
# Initialization 75
#   Iteration 0
# Initialization converged: True
# Initialization 76
#   Iteration 0
# Initialization converged: True
# Initialization 77
#   Iteration 0
#   Iteration 10
#   Iteration 20
# Initialization converged: True
# Initialization 78
#   Iteration 0
# Initialization converged: True
# Initialization 79
#   Iteration 0
# Initialization converged: True
# Initialization 80
#   Iteration 0
# Initialization converged: True
# Initialization 81
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 82
#   Iteration 0
# Initialization converged: True
# Initialization 83
#   Iteration 0
# Initialization converged: True
# Initialization 84
#   Iteration 0
# Initialization converged: True
# Initialization 85
#   Iteration 0
# Initialization converged: True
# Initialization 86
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 87
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 88
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 89
#   Iteration 0
# Initialization converged: True
# Initialization 90
#   Iteration 0
# Initialization converged: True
# Initialization 91
#   Iteration 0
# Initialization converged: True
# Initialization 92
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 93
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 94
#   Iteration 0
# Initialization converged: True
# Initialization 95
#   Iteration 0
# Initialization converged: True
# Initialization 96
#   Iteration 0
# Initialization converged: True
# Initialization 97
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 98
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 99
#   Iteration 0
# Initialization converged: True
# Initialization 100
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 101
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 102
#   Iteration 0
# Initialization converged: True
# Initialization 103
#   Iteration 0
# Initialization converged: True
# Initialization 104
#   Iteration 0
# Initialization converged: True
# Initialization 105
#   Iteration 0
# Initialization converged: True
# Initialization 106
#   Iteration 0
# Initialization converged: True
# Initialization 107
#   Iteration 0
# Initialization converged: True
# Initialization 108
#   Iteration 0
# Initialization converged: True
# Initialization 109
#   Iteration 0
# Initialization converged: True
# Initialization 110
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 111
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 112
#   Iteration 0
# Initialization converged: True
# Initialization 113
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 114
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 115
#   Iteration 0
# Initialization converged: True
# Initialization 116
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 117
#   Iteration 0
# Initialization converged: True
# Initialization 118
#   Iteration 0
# Initialization converged: True
# Initialization 119
#   Iteration 0
# Initialization converged: True
# Initialization 120
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 121
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 122
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 123
#   Iteration 0
# Initialization converged: True
# Initialization 124
#   Iteration 0
# Initialization converged: True
# Initialization 125
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 126
#   Iteration 0
# Initialization converged: True
# Initialization 127
#   Iteration 0
# Initialization converged: True
# Initialization 128
#   Iteration 0
# Initialization converged: True
# Initialization 129
#   Iteration 0
# Initialization converged: True
# Initialization 130
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 131
#   Iteration 0
# Initialization converged: True
# Initialization 132
#   Iteration 0
# Initialization converged: True
# Initialization 133
#   Iteration 0
# Initialization converged: True
# Initialization 134
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 135
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 136
#   Iteration 0
# Initialization converged: True
# Initialization 137
#   Iteration 0
# Initialization converged: True
# Initialization 138
#   Iteration 0
# Initialization converged: True
# Initialization 139
#   Iteration 0
# Initialization converged: True
# Initialization 140
#   Iteration 0
# Initialization converged: True
# Initialization 141
#   Iteration 0
# Initialization converged: True
# Initialization 142
#   Iteration 0
# Initialization converged: True
# Initialization 143
#   Iteration 0
# Initialization converged: True
# Initialization 144
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 145
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 146
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 147
#   Iteration 0
# Initialization converged: True
# Initialization 148
#   Iteration 0
# Initialization converged: True
# Initialization 149
#   Iteration 0
# Initialization converged: True
# Initialization 150
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 151
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 152
#   Iteration 0
#   Iteration 10
#   Iteration 20
# Initialization converged: True
# Initialization 153
#   Iteration 0
# Initialization converged: True
# Initialization 154
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 155
#   Iteration 0
# Initialization converged: True
# Initialization 156
#   Iteration 0
# Initialization converged: True
# Initialization 157
#   Iteration 0
#   Iteration 10
#   Iteration 20
# Initialization converged: True
# Initialization 158
#   Iteration 0
# Initialization converged: True
# Initialization 159
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 160
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 161
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 162
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 163
#   Iteration 0
# Initialization converged: True
# Initialization 164
#   Iteration 0
# Initialization converged: True
# Initialization 165
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 166
#   Iteration 0
# Initialization converged: True
# Initialization 167
#   Iteration 0
# Initialization converged: True
# Initialization 168
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 169
#   Iteration 0
# Initialization converged: True
# Initialization 170
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 171
#   Iteration 0
# Initialization converged: True
# Initialization 172
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 173
#   Iteration 0
# Initialization converged: True
# Initialization 174
#   Iteration 0
# Initialization converged: True
# Initialization 175
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 176
#   Iteration 0
# Initialization converged: True
# Initialization 177
#   Iteration 0
# Initialization converged: True
# Initialization 178
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 179
#   Iteration 0
# Initialization converged: True
# Initialization 180
#   Iteration 0
# Initialization converged: True
# Initialization 181
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 182
#   Iteration 0
# Initialization converged: True
# Initialization 183
#   Iteration 0
# Initialization converged: True
# Initialization 184
#   Iteration 0
# Initialization converged: True
# Initialization 185
#   Iteration 0
# Initialization converged: True
# Initialization 186
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 187
#   Iteration 0
# Initialization converged: True
# Initialization 188
#   Iteration 0
# Initialization converged: True
# Initialization 189
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 190
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 191
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 192
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 193
#   Iteration 0
# Initialization converged: True
# Initialization 194
#   Iteration 0
# Initialization converged: True
# Initialization 195
#   Iteration 0
# Initialization converged: True
# Initialization 196
#   Iteration 0
# Initialization converged: True
# Initialization 197
#   Iteration 0
#   Iteration 10
# Initialization converged: True
# Initialization 198
#   Iteration 0
# Initialization converged: True
# Initialization 199
#   Iteration 0
# Initialization converged: True
# silhouette score = 0.261354079152
# calinski-harabasz score = 341.588710631

# %%
X['label'] = gmm.predict(reduced)
X['label'].value_counts()
X[X.label == 11]
# X.loc['Nikola Jokic/2016-17']
# Out:
# /Users/robertcorboy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                MP_x   2P   3P  3PA    FTr  TS%_x  ORB   TRB  \
# player_year
# Marc Gasol/2015-16             34.4  6.6  0.0  0.1  0.347  0.528  1.2   7.3
# David West/2014-15             28.7  6.1  0.1  0.4  0.235  0.508  2.1   8.5
# Pau Gasol/2015-16              31.8  7.0  0.4  1.1  0.290  0.529  2.4  12.5
# Evan Turner/2015-16            28.0  5.1  0.3  1.3  0.238  0.513  0.8   6.3
# Josh Smith/2014-15             27.7  5.4  1.1  3.6  0.258  0.467  2.4   8.3
# DeMarcus Cousins/2016-17       34.2  7.5  1.9  5.3  0.468  0.562  2.2  11.6
# Julius Randle/2016-17          28.8  6.1  0.3  1.1  0.365  0.543  2.5  10.7
# Nikola Vucevic/2016-17         28.8  7.7  0.4  1.2  0.155  0.498  2.9  13.0
# Marc Gasol/2016-17             34.2  6.1  1.5  3.8  0.286  0.554  0.9   6.6
# Mason Plumlee/2016-17          26.5  5.6  0.0  0.1  0.482  0.558  2.8  10.2
# Al Horford/2015-16             32.1  6.0  1.2  3.5  0.123  0.565  2.0   8.2
# Nikola Jokic/2016-17           27.9  7.9  0.8  2.5  0.267  0.640  3.7  12.7
# DeMarcus Cousins/2014-15       34.1  8.9  0.0  0.1  0.508  0.545  3.3  13.4
# Al Horford/2014-15             30.5  7.9  0.2  0.6  0.146  0.563  2.0   8.4
# Joakim Noah/2014-15            30.6  3.3  0.0  0.0  0.407  0.482  3.8  11.3
# Blake Griffin/2016-17          34.0  7.6  0.7  2.0  0.434  0.569  1.9   8.6
# Draymond Green/2016-17         32.5  2.8  1.2  3.8  0.328  0.522  1.4   8.7
# Marc Gasol/2014-15             33.2  7.1  0.0  0.2  0.410  0.558  1.5   8.4
# Al Horford/2016-17             32.3  4.8  1.4  4.0  0.169  0.553  1.6   7.6
# Blake Griffin/2014-15          35.2  8.6  0.2  0.4  0.373  0.551  1.9   7.8
# Draymond Green/2015-16         34.7  3.9  1.3  3.3  0.402  0.587  1.7   9.9
# Kevin Durant/2016-17           33.4  7.5  2.0  5.4  0.374  0.651  0.7   8.9
# Paul Millsap/2016-17           34.0  5.5  1.2  3.7  0.417  0.542  1.7   8.2
# Giannis Antetokounmpo/2016-17  35.6  7.7  0.6  2.3  0.486  0.599  1.8   8.9
# Giannis Antetokounmpo/2015-16  35.3  6.2  0.4  1.4  0.404  0.566  1.4   7.8
#
#                                AST%  STL%  BLK%   3PAr  DWS  DBPM      dist  \
# player_year
# Marc Gasol/2015-16             18.9   1.4   3.6  0.004  1.9   1.7  1.333537
# David West/2014-15             20.1   1.3   2.0  0.029  2.8   2.4  1.391341
# Pau Gasol/2015-16              21.7   0.9   4.7  0.069  3.9   3.5  1.503939
# Evan Turner/2015-16            23.9   1.7   1.0  0.110  3.0   1.3  1.569333
# Josh Smith/2014-15             20.5   1.9   3.9  0.231  3.4   2.6  1.698300
# DeMarcus Cousins/2016-17       25.8   2.0   3.3  0.254  3.8   2.6  1.733457
# Julius Randle/2016-17          19.3   1.1   1.4  0.082  1.5   0.7  1.744810
# Nikola Vucevic/2016-17         16.9   1.8   2.8  0.073  3.2   2.4  1.780000
# Marc Gasol/2016-17             24.8   1.4   3.7  0.231  3.5   2.2  1.835909
# Mason Plumlee/2016-17          19.8   1.6   3.4  0.010  2.5   2.6  1.836250
# Al Horford/2015-16             16.7   1.3   3.6  0.244  4.5   2.6  1.846636
# Nikola Jokic/2016-17           28.8   1.5   2.1  0.163  2.0   2.2  1.858630
# DeMarcus Cousins/2014-15       20.4   2.3   4.0  0.008  3.2   3.3  1.894921
# Al Horford/2014-15             18.6   1.5   3.5  0.037  3.6   2.5  1.928776
# Joakim Noah/2014-15            23.0   1.2   2.6  0.005  3.1   3.6  2.025366
# Blake Griffin/2016-17          24.5   1.4   0.9  0.116  2.4   1.3  2.027879
# Draymond Green/2016-17         27.6   3.0   3.4  0.405  5.4   5.0  2.044737
# Marc Gasol/2014-15             19.7   1.4   4.0  0.016  4.7   3.5  2.051398
# Al Horford/2016-17             24.4   1.2   3.3  0.302  2.7   2.1  2.094824
# Blake Griffin/2014-15          26.2   1.4   1.2  0.022  2.4   1.0  2.104023
# Draymond Green/2015-16         29.0   2.0   3.0  0.315  5.1   3.9  2.109286
# Kevin Durant/2016-17           23.1   1.5   3.8  0.304  4.0   2.6  2.194286
# Paul Millsap/2016-17           17.9   1.9   2.3  0.248  3.8   2.1  2.221948
# Giannis Antetokounmpo/2016-17  26.6   2.3   4.7  0.143  4.5   3.5  2.325455
# Giannis Antetokounmpo/2015-16  20.0   1.7   3.4  0.108  2.9   1.5  2.354024
#
#                                    dfga  label
# player_year
# Marc Gasol/2015-16             4.390244     11
# David West/2014-15             3.000000     11
# Pau Gasol/2015-16              7.717172     11
# Evan Turner/2015-16            2.466667     11
# Josh Smith/2014-15             6.510000     11
# DeMarcus Cousins/2016-17       5.876543     11
# Julius Randle/2016-17          4.670886     11
# Nikola Vucevic/2016-17         7.151899     11
# Marc Gasol/2016-17             5.136364     11
# Mason Plumlee/2016-17          6.962500     11
# Al Horford/2015-16             7.093458     11
# Nikola Jokic/2016-17           7.342466     11
# DeMarcus Cousins/2014-15       8.142857     11
# Al Horford/2014-15             6.979592     11
# Joakim Noah/2014-15            6.134146     11
# Blake Griffin/2016-17          3.333333     11
# Draymond Green/2016-17         6.873684     11
# Marc Gasol/2014-15             7.440860     11
# Al Horford/2016-17             6.223529     11
# Blake Griffin/2014-15          5.091954     11
# Draymond Green/2015-16         6.000000     11
# Kevin Durant/2016-17           4.740260     11
# Paul Millsap/2016-17           6.883117     11
# Giannis Antetokounmpo/2016-17  4.943182     11
# Giannis Antetokounmpo/2015-16  4.951220     11

# %%
X.to_csv('../data/gaussian_final.csv')
