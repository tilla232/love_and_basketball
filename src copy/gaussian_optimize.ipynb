# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize

# %%
# Constants - The master stat (feature) list, and the corresponding player data.
stats_list = ['MP_x','FG','FGA','2P','2PA','3P','3PA','FT','FTA','ORB', 'DRB', 'TRB', 'AST', 'STL','BLK','TOV','PF','PTS','FG%','2P%','3P%', 'eFG%', 'FT%', 'TS%_x', 'PER', '3PAr','FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','ORtg', 'DRtg', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM','VORP', 'dist', 'spd', 'tchs', 'pass', 'sast', 'ftast', 'dfgm','dfga']
df = pd.read_csv('../data/final_stats.csv')
df.set_index('player_year',inplace=True)
df.fillna(value=0,inplace=True)

# %%
feature_space = ['MP_x','2P','3P','3PA','FTr','TS%_x','ORB','TRB','AST%','STL%','BLK%','3PAr','DWS','DBPM','dist','dfga']

# %%
# Optimizing Gaussian Mixture Model
X = df[feature_space]

cluster_list = range(5,25)
covar_list = ['full','tied','diag','spherical']
comp_list = [2,3,4,5]

for k in cluster_list:
    print ('n clusters = {}'.format(k))
    max_score = [0,0,0,0]
    for covar in covar_list:
        for c in comp_list:
            pca = PCA(n_components=c,whiten=True,svd_solver='full')
            reduced = pca.fit_transform(X)
            
            gmm = GaussianMixture(n_components=k,covariance_type=covar,n_init=100)
            gmm.fit(reduced)
            labels = gmm.predict(reduced)
            try:
                score = silhouette_score(reduced,labels)
            except:
                continue
            if score > max_score[0]:
                max_score = [score,'covar type:{}'.format(covar),'{} pca components'.format(c)]
                print ('new max score: {}'.format(max_score))
# Out:
# n clusters = 5
# new max score: [0.38256595355625328, 'covar type:full', '2 pca components']
# new max score: [0.39785849961855618, 'covar type:tied', '2 pca components']
# n clusters = 6
# new max score: [0.33725247236732986, 'covar type:full', '2 pca components']
# new max score: [0.34307604122257329, 'covar type:tied', '2 pca components']
# n clusters = 7
# new max score: [0.34190531469808544, 'covar type:full', '2 pca components']
# n clusters = 8
# new max score: [0.33654106119757538, 'covar type:full', '2 pca components']
# n clusters = 9
# new max score: [0.35309072934042185, 'covar type:full', '2 pca components']
# n clusters = 10
# new max score: [0.35308795641786439, 'covar type:full', '2 pca components']
# n clusters = 11
# new max score: [0.3502438278376156, 'covar type:full', '2 pca components']
# new max score: [0.35052649425673904, 'covar type:diag', '2 pca components']
# n clusters = 12
# new max score: [0.33458295647438874, 'covar type:full', '2 pca components']
# new max score: [0.34012283766456575, 'covar type:tied', '2 pca components']
# n clusters = 13
# new max score: [0.32849036099736262, 'covar type:full', '2 pca components']
# new max score: [0.35252013189829051, 'covar type:tied', '2 pca components']
# new max score: [0.35619475071405365, 'covar type:diag', '2 pca components']
# n clusters = 14
# new max score: [0.3499508396421917, 'covar type:full', '2 pca components']
# n clusters = 15
# new max score: [0.31025168250333712, 'covar type:full', '2 pca components']
# new max score: [0.33754214889814188, 'covar type:tied', '2 pca components']
# new max score: [0.34689026612833052, 'covar type:diag', '2 pca components']
# n clusters = 16
# new max score: [0.30852246751903095, 'covar type:full', '2 pca components']
# new max score: [0.328360081606411, 'covar type:tied', '2 pca components']
# new max score: [0.3439560505591982, 'covar type:diag', '2 pca components']
# n clusters = 17
# new max score: [0.29241456568606161, 'covar type:full', '2 pca components']
# new max score: [0.32873198021559508, 'covar type:diag', '2 pca components']
# n clusters = 18
# new max score: [0.30914119171341642, 'covar type:full', '2 pca components']
# new max score: [0.31839792944266154, 'covar type:diag', '2 pca components']
# new max score: [0.32528959640319488, 'covar type:spherical', '2 pca components']
# n clusters = 19
# new max score: [0.30200972968593381, 'covar type:full', '2 pca components']
# new max score: [0.31944084472330414, 'covar type:diag', '2 pca components']
# n clusters = 20
# new max score: [0.29659217067811139, 'covar type:full', '2 pca components']
# new max score: [0.31415876280744215, 'covar type:diag', '2 pca components']
# n clusters = 21
# new max score: [0.29495120210603087, 'covar type:full', '2 pca components']
# new max score: [0.30792036244012083, 'covar type:diag', '2 pca components']
# n clusters = 22
# new max score: [0.28914049816357923, 'covar type:full', '2 pca components']
# new max score: [0.30012593652603137, 'covar type:diag', '2 pca components']
# n clusters = 23
# new max score: [0.27496598942494105, 'covar type:full', '2 pca components']
# new max score: [0.28162478328047008, 'covar type:tied', '2 pca components']
# new max score: [0.30632208119635052, 'covar type:diag', '2 pca components']
# new max score: [0.32113094518613078, 'covar type:spherical', '2 pca components']
# n clusters = 24
# new max score: [0.30236657371164594, 'covar type:full', '2 pca components']
# new max score: [0.30330472101556721, 'covar type:tied', '2 pca components']
# new max score: [0.31106259093563088, 'covar type:diag', '2 pca components']
# new max score: [0.32153395132989115, 'covar type:spherical', '2 pca components']

# %%
gmm = GaussianMixture(n_components=12,covariance_type='full')
gmm_pca = GaussianMixture(n_components=13,covariance_type='full',n_init=100)

pca = PCA(n_components=2)
reduced = pca.fit_transform(X)

gmm.fit(X)
gmm_pca.fit(reduced)
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#         means_init=None, n_components=13, n_init=100, precisions_init=None,
#         random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
silhouette_score(X,gmm.predict(X))
# Out:
# -0.020533796388575339

# %%
silhouette_score(reduced,gmm_pca.predict(reduced))
# Out:
# 0.32711881152878819

# %%
X['label'] = gmm_pca.predict(reduced)
# Out:
# /Users/robertcorboy/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
X.loc['Nikola Jokic/2016-17']
# Out:
# MP_x     27.900000
# tchs     66.315068
# 2P        7.900000
# 3P        0.800000
# 3PA       2.500000
# FTr       0.267000
# TS%_x     0.640000
# ORB       3.700000
# TRB      12.700000
# AST%     28.800000
# STL%      1.500000
# BLK%      2.100000
# 3PAr      0.163000
# DWS       2.000000
# DBPM      2.200000
# dist      1.858630
# dfga      7.342466
# label     4.000000
# Name: Nikola Jokic/2016-17, dtype: float64

# %%
X['label'].value_counts()
# Out:
# 3     130
# 11    119
# 1     107
# 6     103
# 5      98
# 7      78
# 8      59
# 2      51
# 12     46
# 4      44
# 9      43
# 0      27
# 10      6
# Name: label, dtype: int64

# %%
X[X['label'] == 1]
# Out:
#                                MP_x       tchs   2P   3P  3PA    FTr  TS%_x  \
# player_year
# Marc Gasol/2015-16             34.4  44.304878  6.6  0.0  0.1  0.347  0.528
# David West/2014-15             28.7  48.170732  6.1  0.1  0.4  0.235  0.508
# ...                                 ...       ...    ...
# Wesley Matthews/2015-16        2.102391  1.369565      1
# Marcin Gortat/2016-17          2.102526  7.600000      1
# Andre Drummond/2015-16         2.107931  8.022989      1
# Thaddeus Young/2016-17         2.110260  3.376623      1
# Danny Green/2014-15            2.116854  3.078652      1
# Jae Crowder/2015-16            2.127125  2.487500      1
# Giannis Antetokounmpo/2014-15  2.133068  4.159091      1
# Tobias Harris/2014-15          2.144605  3.105263      1
# Gorgui Dieng/2016-17           2.150964  7.301205      1
# Marcus Morris/2016-17          2.155732  2.158537      1
# Trevor Ariza/2015-16           2.181383  1.957447      1
# Jae Crowder/2016-17            2.186180  2.438202      1
# Victor Oladipo/2016-17         2.201053  2.434211      1
# DeAndre Jordan/2014-15         2.202708  8.802083      1
# Trevor Ariza/2016-17           2.235652  2.597826      1
# Klay Thompson/2015-16          2.236071  2.294643      1
# Eric Gordon/2014-15            2.253692  1.323077      1
# Jabari Parker/2015-16          2.271282  3.653846      1
# Andrew Wiggins/2015-16         2.280488  2.353659      1
# Avery Bradley/2016-17          2.301370  2.547945      1
# Harrison Barnes/2016-17        2.314756  2.975610      1
# Klay Thompson/2014-15          2.324900  1.960000      1
# Otto Porter/2016-17            2.343871  3.215054      1
# Kawhi Leonard/2014-15          2.348451  2.718310      1
# Klay Thompson/2016-17          2.368229  2.666667      1
# Evan Fournier/2015-16          2.371250  1.950000      1
# Wesley Matthews/2014-15        2.374333  1.400000      1
# Marcus Morris/2015-16          2.378161  2.126437      1
# Andrew Wiggins/2016-17         2.386506  3.301205      1
# Andrew Wiggins/2014-15         2.438902  3.207317      1
#
# [107 rows x 18 columns]

# %%
X.head()
# Out:
#                          MP_x       tchs   2P   3P  3PA    FTr  TS%_x  ORB  \
# player_year
# Nick Collison/2015-16    11.8   7.333333  2.6  0.0  0.1  0.303  0.498  3.5
# Jimmer Fredette/2014-15  10.2   8.779070  3.8  0.6  3.4  0.271  0.479  0.6
# Brandon Bass/2016-17     11.1  10.397727  6.6  0.1  0.2  0.473  0.650  2.7
# Tyler Zeller/2016-17     10.3  10.795455  5.3  0.0  0.1  0.247  0.508  2.9
# Justin Holiday/2014-15   11.1   8.861386  3.1  1.9  6.0  0.191  0.498  0.7
#
#                          TRB  AST%  STL%  BLK%   3PAr  DWS  DBPM      dist  \
# player_year
# Nick Collison/2015-16    8.8   9.6   1.1   1.7  0.018  0.7   1.3  0.381348
# Jimmer Fredette/2014-15  2.8  17.2   1.5   0.3  0.289  0.2  -2.9  0.432442
# Brandon Bass/2016-17     8.0   5.7   1.2   1.6  0.016  0.6  -0.8  0.463523
# Tyler Zeller/2016-17     8.5  12.2   0.7   3.3  0.006  0.6   0.8  0.472500
# Justin Holiday/2014-15   4.0  10.1   3.0   1.4  0.464  1.0   0.5  0.483663
#
#                              dfga  label
# player_year
# Nick Collison/2015-16    0.985816      6
# Jimmer Fredette/2014-15  0.279070      0
# Brandon Bass/2016-17     0.852273      6
# Tyler Zeller/2016-17     1.477273      6
# Justin Holiday/2014-15   0.514851      6

# %%
X.to_csv('../data/final_gaussian.csv')
