# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
from sklearn.cluster import AffinityPropagation
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# %%
# Constants - The master stat (feature) list, and the corresponding player data.
stats_list = ['MP_x','FG','FGA','2P','2PA','3P','3PA','FT','FTA','ORB', 'DRB', 'TRB', 'AST', 'STL','BLK','TOV','PF','PTS','FG%','2P%','3P%', 'eFG%', 'FT%', 'TS%_x', 'PER', '3PAr','FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%','ORtg', 'DRtg', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM','VORP', 'dist', 'spd', 'tchs', 'pass', 'sast', 'ftast', 'dfgm','dfga']
df = pd.read_csv('../data/final_stats.csv')
df.set_index('player_year',inplace=True)
df.fillna(value=0,inplace=True)

# %%
feature_space = ['MP_x','tchs','2P','3P','3PA','FTr','TS%_x','ORB','TRB','AST%','STL%','BLK%','3PAr','DWS','DBPM','dist','dfga']

# %%
# Optimizing Affinity Propagation
X = df[feature_space]

damping_list = np.linspace(0.5,0.98,20)
preference_list = np.arange(-300,300,25)
comp_list = [2,3,4,5]
max_score = [0,0,0,0]

for d in damping_list:
    print 'damping = {}'.format(d)
    for p in preference_list:
        for c in comp_list:
            pca = PCA(n_components=c,whiten=True,svd_solver='full')
            reduced = pca.fit_transform(X)
            
            aff = AffinityPropagation(damping=d,preference=p)
            aff.fit(reduced)
            try:
                score = silhouette_score(reduced,aff.labels_)
            except:
                continue
            n_clusters = len(np.unique(aff.labels_))
            if n_clusters in range(5,30):
                if score > max_score[0]:
                    max_score = [score,'damping:{}'.format(d),'preference:{}'.format(p),'{} pca components'.format(c)]
                    print 'new max score: {}'.format(max_score) + '{} clusters'.format(n_clusters)
# Out:
# damping = 0.5
# new max score: [0.1746145220534368, 'damping:0.5', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.24662592585852194, 'damping:0.5', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.25518685450737078, 'damping:0.5', 'preference:-250', '4 pca components']5 clusters
# new max score: [0.32241839889461948, 'damping:0.5', 'preference:-200', '3 pca components']5 clusters
# damping = 0.525263157895
# damping = 0.550526315789
# new max score: [0.35023044489348742, 'damping:0.550526315789', 'preference:-25', '2 pca components']11 clusters
# damping = 0.575789473684
# damping = 0.601052631579
# damping = 0.626315789474
# new max score: [0.3809279943434567, 'damping:0.626315789474', 'preference:-100', '2 pca components']5 clusters
# damping = 0.651578947368
# damping = 0.676842105263
# damping = 0.702105263158
# damping = 0.727368421053
# damping = 0.752631578947
# damping = 0.777894736842
# damping = 0.803157894737
# new max score: [0.39355534892826055, 'damping:0.803157894737', 'preference:-100', '2 pca components']5 clusters
# damping = 0.828421052632
# new max score: [0.39930694090650448, 'damping:0.828421052632', 'preference:-100', '2 pca components']5 clusters
# damping = 0.853684210526
# damping = 0.878947368421
# damping = 0.904210526316
# damping = 0.929473684211
# damping = 0.954736842105
# damping = 0.98

# %%
# Optimizing Affinity Propagation, round 2
X = df[feature_space]

damping_list = np.linspace(0.5,0.6,20)
preference_list = np.arange(-300,300,25)
comp_list = [2,3,4,5]

for d in damping_list:
    max_score = [0,0,0,0] # reset high score with each damping value this time
    print 'damping = {}'.format(d)
    for p in preference_list:
        for c in comp_list:
            pca = PCA(n_components=c,whiten=True,svd_solver='full')
            reduced = pca.fit_transform(X)
            
            aff = AffinityPropagation(damping=d,preference=p)
            aff.fit(reduced)
            try:
                score = silhouette_score(reduced,aff.labels_)
            except:
                continue
            n_clusters = len(np.unique(aff.labels_))
            if n_clusters in range(5,30):
                if score > max_score[0]:
                    max_score = [score,'damping:{}'.format(d),'preference:{}'.format(p),'{} pca components'.format(c)]
                    print 'new max score: {}'.format(max_score) + '{} clusters'.format(n_clusters)
# Out:
# damping = 0.5
# new max score: [0.1746145220534368, 'damping:0.5', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.24662592585852194, 'damping:0.5', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.25518685450737078, 'damping:0.5', 'preference:-250', '4 pca components']5 clusters
# new max score: [0.32241839889461948, 'damping:0.5', 'preference:-200', '3 pca components']5 clusters
# damping = 0.505263157895
# new max score: [0.17993088517307038, 'damping:0.505263157895', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.23423736652086205, 'damping:0.505263157895', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.23969614680902226, 'damping:0.505263157895', 'preference:-250', '4 pca components']5 clusters
# new max score: [0.32652811036707857, 'damping:0.505263157895', 'preference:-200', '3 pca components']5 clusters
# damping = 0.510526315789
# new max score: [0.19439026338429122, 'damping:0.510526315789', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.32837439131829477, 'damping:0.510526315789', 'preference:-250', '3 pca components']5 clusters
# damping = 0.515789473684
# new max score: [0.24194558686091172, 'damping:0.515789473684', 'preference:-300', '4 pca components']5 clusters
# new max score: [0.27731856531381255, 'damping:0.515789473684', 'preference:-250', '3 pca components']5 clusters
# new max score: [0.30003771373038968, 'damping:0.515789473684', 'preference:-175', '3 pca components']5 clusters
# new max score: [0.30591525845064982, 'damping:0.515789473684', 'preference:-150', '3 pca components']6 clusters
# new max score: [0.3169854962818785, 'damping:0.515789473684', 'preference:-125', '3 pca components']6 clusters
# damping = 0.521052631579
# new max score: [0.22857935286435485, 'damping:0.521052631579', 'preference:-300', '4 pca components']5 clusters
# new max score: [0.29173652108164144, 'damping:0.521052631579', 'preference:-250', '3 pca components']5 clusters
# new max score: [0.3175235971792168, 'damping:0.521052631579', 'preference:-125', '3 pca components']6 clusters
# damping = 0.526315789474
# new max score: [0.17250477527615013, 'damping:0.526315789474', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.17634440272695054, 'damping:0.526315789474', 'preference:-275', '5 pca components']5 clusters
# new max score: [0.22597756498619223, 'damping:0.526315789474', 'preference:-250', '4 pca components']6 clusters
# new max score: [0.25720271074404272, 'damping:0.526315789474', 'preference:-225', '4 pca components']5 clusters
# new max score: [0.31731453557580414, 'damping:0.526315789474', 'preference:-175', '3 pca components']6 clusters
# damping = 0.531578947368
# new max score: [0.17958290695578674, 'damping:0.531578947368', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.25151644230947884, 'damping:0.531578947368', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.32190470110841385, 'damping:0.531578947368', 'preference:-200', '3 pca components']5 clusters
# new max score: [0.32213794128331924, 'damping:0.531578947368', 'preference:-25', '2 pca components']11 clusters
# damping = 0.536842105263
# new max score: [0.18808529098229917, 'damping:0.536842105263', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.23872230855827248, 'damping:0.536842105263', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.29173652108164144, 'damping:0.536842105263', 'preference:-250', '3 pca components']5 clusters
# new max score: [0.29271126225120325, 'damping:0.536842105263', 'preference:-150', '3 pca components']6 clusters
# new max score: [0.31384556786326223, 'damping:0.536842105263', 'preference:-125', '3 pca components']6 clusters
# new max score: [0.31738468289702854, 'damping:0.536842105263', 'preference:-100', '3 pca components']6 clusters
# damping = 0.542105263158
# new max score: [0.23654042593893496, 'damping:0.542105263158', 'preference:-300', '4 pca components']5 clusters
# new max score: [0.25360813981510089, 'damping:0.542105263158', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.28661044246484374, 'damping:0.542105263158', 'preference:-200', '3 pca components']5 clusters
# new max score: [0.31630848356682556, 'damping:0.542105263158', 'preference:-175', '3 pca components']6 clusters
# new max score: [0.32939819366401524, 'damping:0.542105263158', 'preference:-150', '3 pca components']5 clusters
# damping = 0.547368421053
# new max score: [0.19313488397706452, 'damping:0.547368421053', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.23957040924360842, 'damping:0.547368421053', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.24009107254280002, 'damping:0.547368421053', 'preference:-250', '4 pca components']5 clusters
# new max score: [0.24166578452015311, 'damping:0.547368421053', 'preference:-225', '4 pca components']5 clusters
# new max score: [0.25901478039932624, 'damping:0.547368421053', 'preference:-200', '4 pca components']5 clusters
# new max score: [0.28767078341863861, 'damping:0.547368421053', 'preference:-175', '3 pca components']5 clusters
# new max score: [0.31248494562502693, 'damping:0.547368421053', 'preference:-150', '3 pca components']6 clusters
# new max score: [0.31695671842503637, 'damping:0.547368421053', 'preference:-125', '3 pca components']6 clusters
# damping = 0.552631578947
# new max score: [0.24044146476906811, 'damping:0.552631578947', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.2507345172984709, 'damping:0.552631578947', 'preference:-225', '4 pca components']5 clusters
# new max score: [0.32173801816455644, 'damping:0.552631578947', 'preference:-200', '3 pca components']5 clusters
# new max score: [0.32224897446993261, 'damping:0.552631578947', 'preference:-175', '3 pca components']5 clusters
# damping = 0.557894736842
# new max score: [0.18750001811390274, 'damping:0.557894736842', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.24594262791571544, 'damping:0.557894736842', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.32870415904562816, 'damping:0.557894736842', 'preference:-200', '3 pca components']5 clusters
# damping = 0.563157894737
# new max score: [0.19198069509696056, 'damping:0.563157894737', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.21766627989281709, 'damping:0.563157894737', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.30025178222860954, 'damping:0.563157894737', 'preference:-250', '3 pca components']5 clusters
# new max score: [0.30202773489087986, 'damping:0.563157894737', 'preference:-150', '3 pca components']5 clusters
# new max score: [0.31415936820033447, 'damping:0.563157894737', 'preference:-125', '3 pca components']6 clusters
# damping = 0.568421052632
# new max score: [0.25233184124912528, 'damping:0.568421052632', 'preference:-300', '4 pca components']5 clusters
# new max score: [0.3152205738503408, 'damping:0.568421052632', 'preference:-250', '3 pca components']5 clusters
# new max score: [0.32184370540425744, 'damping:0.568421052632', 'preference:-150', '3 pca components']5 clusters
# new max score: [0.35180857480810196, 'damping:0.568421052632', 'preference:-25', '2 pca components']10 clusters
# damping = 0.573684210526
# new max score: [0.18254900114152128, 'damping:0.573684210526', 'preference:-300', '5 pca components']6 clusters
# new max score: [0.31660191224610668, 'damping:0.573684210526', 'preference:-275', '3 pca components']5 clusters
# new max score: [0.32606943996588456, 'damping:0.573684210526', 'preference:-225', '3 pca components']5 clusters
# new max score: [0.32885962556091336, 'damping:0.573684210526', 'preference:-150', '3 pca components']5 clusters
# new max score: [0.35285042064762379, 'damping:0.573684210526', 'preference:-25', '2 pca components']8 clusters
# damping = 0.578947368421
# new max score: [0.23895776663118365, 'damping:0.578947368421', 'preference:-300', '4 pca components']5 clusters
# new max score: [0.32373851048202817, 'damping:0.578947368421', 'preference:-275', '3 pca components']5 clusters
# new max score: [0.34321322176483099, 'damping:0.578947368421', 'preference:-125', '2 pca components']5 clusters
# damping = 0.584210526316
# new max score: [0.23166454607357356, 'damping:0.584210526316', 'preference:-300', '4 pca components']5 clusters
# new max score: [0.24438429846294332, 'damping:0.584210526316', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.27608640126654965, 'damping:0.584210526316', 'preference:-225', '3 pca components']5 clusters
# new max score: [0.27618731216109266, 'damping:0.584210526316', 'preference:-200', '3 pca components']5 clusters
# new max score: [0.31308721036831921, 'damping:0.584210526316', 'preference:-150', '3 pca components']5 clusters
# new max score: [0.31668159882376218, 'damping:0.584210526316', 'preference:-125', '3 pca components']6 clusters
# new max score: [0.34460594186009891, 'damping:0.584210526316', 'preference:-100', '2 pca components']6 clusters
# damping = 0.589473684211
# new max score: [0.18563286065616461, 'damping:0.589473684211', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.25051043907127429, 'damping:0.589473684211', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.2607443371699345, 'damping:0.589473684211', 'preference:-250', '4 pca components']5 clusters
# new max score: [0.29937695005454695, 'damping:0.589473684211', 'preference:-200', '3 pca components']5 clusters
# new max score: [0.30279158828343289, 'damping:0.589473684211', 'preference:-175', '3 pca components']5 clusters
# new max score: [0.32101303404660392, 'damping:0.589473684211', 'preference:-150', '3 pca components']6 clusters
# damping = 0.594736842105
# new max score: [0.25260878411621451, 'damping:0.594736842105', 'preference:-300', '4 pca components']5 clusters
# new max score: [0.32023299787331383, 'damping:0.594736842105', 'preference:-275', '3 pca components']5 clusters
# damping = 0.6
# new max score: [0.17657198031526078, 'damping:0.6', 'preference:-300', '5 pca components']5 clusters
# new max score: [0.24791062649647855, 'damping:0.6', 'preference:-275', '4 pca components']5 clusters
# new max score: [0.2711733859154456, 'damping:0.6', 'preference:-225', '3 pca components']5 clusters
# new max score: [0.27522683549304078, 'damping:0.6', 'preference:-175', '3 pca components']5 clusters
# new max score: [0.31661371226291196, 'damping:0.6', 'preference:-150', '3 pca components']6 clusters
# new max score: [0.31762172431067126, 'damping:0.6', 'preference:-125', '3 pca components']6 clusters
# new max score: [0.33019609020963575, 'damping:0.6', 'preference:-25', '2 pca components']10 clusters

# %%
X = df[feature_space]

# %%
pca = PCA(n_components=2,whiten=True,svd_solver='full')
reduced = pca.fit_transform(X)

aff = AffinityPropagation(damping=0.68,preference=-1500)
aff.fit(X)
# Out:
# AffinityPropagation(affinity='euclidean', convergence_iter=15, copy=True,
#           damping=0.68, max_iter=200, preference=-1500, verbose=False)

# %%
silhouette_score(X,aff.labels_)
# Out:
# 0.19431199682417732

# %%
X['label'] = aff.labels_
# Out:
# /Users/robertcorboy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
X.loc['Nikola Jokic/2016-17']
X['label'].value_counts()
# Out:
# 5     81
# 14    73
# 7     73
# 9     70
# 0     63
# 8     61
# 3     53
# 10    52
# 4     47
# 16    43
# 12    42
# 17    42
# 13    40
# 6     35
# 15    34
# 1     33
# 11    32
# 2     31
# 18     6
# Name: label, dtype: int64

# %%
X[X['label'] == 11]
# Out:
#                                 MP_x       tchs   2P   3P  3PA    FTr  TS%_x  \
# player_year
# Jeff Teague/2015-16             28.5  58.495327  5.2  1.8  4.4  0.316  0.551
# Rajon Rondo/2015-16             35.2  61.964286  4.2  0.9  2.4  0.192  0.506
# Mo Williams/2014-15             29.1  60.833333  4.0  2.2  6.3  0.217  0.512
# Rajon Rondo/2016-17             26.7  64.628205  3.5  1.0  2.6  0.089  0.461
# Chris Paul/2015-16              32.7  67.470588  5.8  1.8  4.9  0.294  0.575
# Russell Westbrook/2015-16       34.4  63.610294  7.3  1.3  4.5  0.397  0.554
# James Harden/2015-16            38.1  59.968000  5.5  2.7  7.6  0.518  0.598
# Isaiah Thomas/2014-15           25.8  61.028169  4.3  2.7  7.2  0.437  0.579
# Ish Smith/2015-16               29.1  65.979381  5.5  0.9  2.7  0.182  0.465
# Chris Paul/2016-17              31.5  74.358974  4.7  2.3  5.7  0.331  0.614
# Darren Collison/2016-17         30.3  64.194805  4.7  1.3  3.1  0.239  0.570
# Ish Smith/2016-17               24.1  63.085366  5.5  0.5  1.9  0.136  0.477
# Jarrett Jack/2014-15            28.0  59.613636  5.1  0.6  2.3  0.278  0.522
# Eric Bledsoe/2016-17            33.0  68.100000  5.7  1.7  5.1  0.443  0.563
# Nikola Jokic/2016-17            27.9  66.315068  7.9  0.8  2.5  0.267  0.640
# Reggie Jackson/2014-15          29.5  65.634146  5.7  1.1  3.8  0.219  0.511
# Reggie Jackson/2016-17          27.4  67.705882  5.5  1.7  4.7  0.201  0.510
# Evan Turner/2014-15             27.6  63.790698  4.6  0.5  1.9  0.189  0.482
# Jrue Holiday/2016-17            32.7  66.000000  5.0  1.6  4.6  0.188  0.532
# Jeff Teague/2014-15             30.5  72.074468  5.4  1.1  3.3  0.360  0.566
# Michael CarterWilliams/2014-15  32.6  70.988636  5.5  0.6  2.6  0.317  0.461
# Reggie Jackson/2015-16          30.7  70.505495  6.3  1.8  5.0  0.271  0.535
# Elfrid Payton/2015-16           29.4  65.265060  4.8  0.5  1.5  0.260  0.478
# Dwyane Wade/2014-15             31.8  61.076923  8.8  0.5  1.9  0.341  0.534
# Tony Parker/2014-15             28.7  65.650602  6.7  0.7  1.6  0.200  0.539
# D'Angelo Russell/2016-17        28.7  67.354839  4.3  2.7  7.6  0.217  0.518
# Emmanuel Mudiay/2015-16         30.4  68.905405  4.4  1.3  4.0  0.231  0.437
# Brandon Knight/2014-15          32.3  66.188406  4.4  2.2  5.7  0.251  0.543
# Kyrie Irving/2016-17            35.1  69.443299  7.0  2.5  6.3  0.231  0.580
# Elfrid Payton/2016-17           29.4  71.000000  5.8  0.6  2.2  0.231  0.520
# Elfrid Payton/2014-15           30.4  67.743902  4.2  0.2  0.6  0.302  0.456
# Nicolas Batum/2016-17           34.0  61.037500  3.5  1.9  5.6  0.291  0.529
#
#                                 ORB   TRB  AST%  STL%  BLK%   3PAr  DWS  DBPM  \
# player_year
# Jeff Teague/2015-16             0.5   3.4  34.4   2.1   0.8  0.278  3.0  -0.9
# Rajon Rondo/2015-16             1.1   6.2  48.0   2.7   0.3  0.217  2.3   0.2
# Mo Williams/2014-15             0.4   3.2  37.4   1.2   0.6  0.405  0.6  -3.5
# Rajon Rondo/2016-17             1.4   6.9  37.0   2.7   0.5  0.237  2.7   1.6
# Chris Paul/2015-16              0.6   4.6  52.7   3.1   0.4  0.295  3.5   0.5
# Russell Westbrook/2015-16       1.9   8.2  49.6   2.9   0.6  0.236  4.0   2.4
# James Harden/2015-16            0.7   5.8  35.4   2.2   1.4  0.406  2.6  -0.4
# Isaiah Thomas/2014-15           0.7   3.2  27.2   1.6   0.2  0.434  1.1  -2.8
# Ish Smith/2015-16               0.7   4.9  38.3   1.9   0.8  0.176  1.3  -1.1
# Chris Paul/2016-17              0.8   5.7  46.8   3.1   0.3  0.385  2.6   1.0
# Darren Collison/2016-17         0.4   2.7  24.5   1.6   0.4  0.245  0.8  -2.3
# Ish Smith/2016-17               0.4   4.3  32.5   1.6   1.4  0.140  2.2   0.4
# Jarrett Jack/2014-15            0.3   3.9  27.3   1.7   0.5  0.179  1.4  -1.0
# Eric Bledsoe/2016-17            0.9   5.3  31.1   2.0   1.2  0.300  1.4  -0.4
# Nikola Jokic/2016-17            3.7  12.7  28.8   1.5   2.1  0.163  2.0   2.2
# Reggie Jackson/2014-15          0.9   5.2  34.8   1.4   0.3  0.242  1.7  -1.2
# Reggie Jackson/2016-17          0.5   2.9  30.3   1.2   0.3  0.272  1.2  -2.1
# Evan Turner/2014-15             0.6   6.6  30.0   1.8   0.7  0.160  2.8   1.3
# Jrue Holiday/2016-17            0.8   4.3  35.9   2.2   1.6  0.314  2.6   0.5
# Jeff Teague/2014-15             0.5   3.0  37.9   2.9   1.2  0.233  2.8  -0.7
# Michael CarterWilliams/2014-15  1.1   5.9  37.3   2.6   1.1  0.166  2.9   0.9
# Reggie Jackson/2015-16          0.9   3.8  36.3   1.2   0.3  0.268  1.9  -1.6
# Elfrid Payton/2015-16           1.3   4.4  32.8   2.1   0.8  0.126  1.7  -0.5
# Dwyane Wade/2014-15             1.1   4.0  32.1   2.0   0.9  0.094  1.4  -1.2
# Tony Parker/2014-15             0.3   2.4  28.7   1.2   0.1  0.107  1.7  -2.2
# D'Angelo Russell/2016-17        0.6   4.4  26.8   2.3   0.7  0.443  1.0  -1.6
# Emmanuel Mudiay/2015-16         0.6   4.0  29.0   1.6   1.4  0.256  1.2  -1.2
# Brandon Knight/2014-15          0.5   4.3  27.4   2.3   0.4  0.361  2.5  -0.7
# Kyrie Irving/2016-17            0.7   3.3  29.7   1.6   0.8  0.311  1.5  -2.3
# Elfrid Payton/2016-17           1.3   5.8  35.7   1.8   1.3  0.160  2.0   0.2
# Elfrid Payton/2014-15           1.5   5.0  32.6   2.9   0.7  0.059  2.3   0.8
# Nicolas Batum/2016-17           0.6   6.6  27.6   1.6   1.0  0.415  2.8   0.6
#
#                                     dist      dfga  label
# player_year
# Jeff Teague/2015-16             1.559346  0.822430     11
# Rajon Rondo/2015-16             1.567857  0.937500     11
# Mo Williams/2014-15             1.593214  0.964286     11
# Rajon Rondo/2016-17             1.639103  1.025641     11
# Chris Paul/2015-16              1.649706  1.245098     11
# Russell Westbrook/2015-16       1.700074  1.455882     11
# James Harden/2015-16            1.700400  2.320000     11
# Isaiah Thomas/2014-15           1.730423  0.802817     11
# Ish Smith/2015-16               1.760103  1.938144     11
# Chris Paul/2016-17              1.784872  1.500000     11
# Darren Collison/2016-17         1.797403  0.727273     11
# Ish Smith/2016-17               1.812683  1.878049     11
# Jarrett Jack/2014-15            1.841932  1.079545     11
# Eric Bledsoe/2016-17            1.852875  1.687500     11
# Nikola Jokic/2016-17            1.858630  7.342466     11
# Reggie Jackson/2014-15          1.887439  2.170732     11
# Reggie Jackson/2016-17          1.894902  1.627451     11
# Evan Turner/2014-15             1.895465  3.244186     11
# Jrue Holiday/2016-17            1.898148  1.592593     11
# Jeff Teague/2014-15             1.913404  0.765957     11
# Michael CarterWilliams/2014-15  1.934318  1.988636     11
# Reggie Jackson/2015-16          1.951538  2.263736     11
# Elfrid Payton/2015-16           1.976867  1.686747     11
# Dwyane Wade/2014-15             1.980769  1.861538     11
# Tony Parker/2014-15             1.988554  1.144578     11
# D'Angelo Russell/2016-17        1.996935  1.532258     11
# Emmanuel Mudiay/2015-16         2.073649  2.256757     11
# Brandon Knight/2014-15          2.075507  1.347826     11
# Kyrie Irving/2016-17            2.091649  1.876289     11
# Elfrid Payton/2016-17           2.111951  2.158537     11
# Elfrid Payton/2014-15           2.200000  2.170732     11
# Nicolas Batum/2016-17           2.331250  2.537500     11
